# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import statistics

# %%
#Analysis of moving data in open space

# %%
moveone_data = pd.read_csv('2022-02-18-18-34-40 2022-02-21 22_19_12-gps_data_lab2.csv')

# %%
e1=moveone_data['.utm_easting']
n1=moveone_data['.utm_northing']
a1=moveone_data['.altitude']

# %%
plt.rcParams['figure.figsize'] = [10,10]

# %%
#ploting of easting vs northing
plt.plot(e1,n1,'go')
plt.show
plt.grid()

plt.title('Position Coordinates')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
# Out:
# Text(0, 0.5, 'UTM Northing in metres')

# %%
#altitude plot with mean line
plt.plot(a1,'r.')
plt.show
plt.title('Altitude Plot')
plt.xlabel('Time in seconds')
plt.ylabel('Altitude in meters')
plt.show
plt.hlines(moveone_data['.altitude'].mean(), xmin=0 , xmax=124)
plt.grid()

# %%
#SDE=moveone_data['.utm_easting'].std()
#SDN=moveone_data['.utm_northing'].std()
SDA=moveone_data['.altitude'].std()

# %%
#SDE

# %%
#SDN

# %%
SDA
# Out:
# 0.6006791854817075

# %%
#I am going to divide the square looking path to four lines and analyze for each sides for better understanding and visualization.

# %%
e11 = np.array(e1)
n11 = np.array(n1)
a11 = np.array(a1)

# %%
e11
# Out:
# array([327620.54284444, 327620.54739855, 327620.54739855, 327620.68015119,
#        327620.68015119, 327620.68015119, 327620.68015119, 327620.95476468,
#        327621.08751733, 327621.49943757, 327622.0441105 , 327622.45603075,
#        327622.86339696, 327623.41262398, 327623.82454425, 327624.2319105 ,
#        327624.78113754, 327625.32581059, 327625.87503764, 327626.41971074,
#        327626.96438387, 327627.65091771, 327628.20014479, 327628.74481798,
#        327629.43135184, 327629.98057893, 327630.66255896, 327631.07447929,
#        327631.75645936, 327632.30113268, 327632.85035982, 327633.53689373,
#        327634.22342765, 327634.76810105, 327635.45008128, 327636.13661523,
#        327636.68584239, 327637.36782268, 327637.90794257, 327638.44806251,
#        327638.99273613, 327639.53740977, 327640.08208345, 327640.35214351,
#        327640.62220358, 327640.89681723, 327641.16687733, 327641.30873771,
# ...

# %%
#first side
e111 = e11[0:46]
n111 = n11[0:46]
a111 = a11[0:46]
plt.plot(e111,n111, '.')


plt.title('Position Coordinates of first side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')



x = np.array(e111)
y = np.array(n111)
m, b = np.polyfit(e111,n111, 1)
plt.plot(x, m*e111 + b)
plt.grid()

# %%
new_y1 = m*e111 + b

# %%
new_y1.size
# Out:
# 46

# %%
np.array(n111).size
# Out:
# 46

# %%
#calculation of mean square error
np.array(new_y1)
MS=np.square(np.array(new_y1)-np.array(n111))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/46
print(MSE)
# Out:
# 0.057957408541276074

# %%
#second side
e112 = e11[47:61]
n112 = n11[47:61]
a112 = a11[47:61]
plt.plot(e112,n112,'go')
plt.show

plt.title('Position Coordinates of the second side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')

x = np.array(e112)
y = np.array(n112)
m, b = np.polyfit(e112,n112, 1)
plt.plot(x, m*e112 + b)
plt.grid()

# %%
new_y2 = m*e112 + b

# %%
new_y2.size
# Out:
# 14

# %%
np.array(n112).size
# Out:
# 14

# %%
#calculation of mean square error
np.array(new_y2)
MS=np.square(np.array(new_y2)-np.array(n112))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/14
print(MSE)
# Out:
# 0.1155429212713511

# %%
#third side
e113 = e11[61:90]
n113 = n11[61:90]
a113 = a11[61:90]
plt.plot(e113,n113,'go')
plt.show

plt.title('Position Coordinates of the third side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
x = np.array(e113)
y = np.array(n113)
m, b = np.polyfit(e113,n113, 1)
plt.plot(x, m*e113 + b)
plt.grid()

# %%
new_y3 = m*e113 + b

# %%
new_y3.size
# Out:
# 29

# %%
np.array(n113).size
# Out:
# 29

# %%
#calculation of mean square error
np.array(new_y3)
MS=np.square(np.array(new_y3)-np.array(n113))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/29
print(MSE)
# Out:
# 0.020428921544716143

# %%
#fourth side
e114 = e11[90:124]
n114 = n11[90:124]
a114 = a11[90:124]
plt.plot(e114,n114,'go')
plt.show

plt.title('Position Coordinates of the fourth side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')

x = np.array(e114)
y = np.array(n114)
m, b = np.polyfit(e114,n114, 1)
plt.plot(x, m*e114 + b)
plt.grid()

# %%
new_y4 = m*e114 + b

# %%
new_y4.size
# Out:
# 34

# %%
np.array(n114).size
# Out:
# 34

# %%
#calculation of mean square error
np.array(new_y4)
MS=np.square(np.array(new_y4)-np.array(n114))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/34
print(MSE)
# Out:
# 0.02182972052108329

# %%
#analysis of stationary data in open space.

# %%
statone_data = pd.read_csv('2022-02-18-17-18-59 2022-02-21 22_19_32-gps_data_lab2.csv')

# %%
e2=statone_data['.utm_easting']
n2=statone_data['.utm_northing']
a2=statone_data['.altitude']

# %%
#plot of easting vs northing
plt.plot(e2,n2,'go')
plt.show

plt.title('Position Coordinates')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')

plt.grid()

# %%
plt.hist(e2)
plt.xlabel('UTM Easting in metres')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.hist(n2)
plt.xlabel('UTM Northing in metres')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
SDE=statone_data['.utm_easting'].std() 
SDN=statone_data['.utm_northing'].std()

# %%
SDE #standard deviation of utm easting
# Out:
# 0.0001798549450621717

# %%
SDN #standard deviation of utm northing
# Out:
# 0.007315559727745076

# %%
#plot of Altitude with mean line
plt.plot(a2,'g.')
plt.title('Altitude Plot')
plt.hlines(statone_data['.altitude'].mean(), xmin=0 , xmax=628)
plt.xlabel('Time in seconds')
plt.ylabel('Altitude in meters')
plt.grid()

# %%
SDA=statone_data['.altitude'].std()

# %%
SDA #standard deviation of altitude
# Out:
# 0.04715886272306954

# %%
#Analysis of moving data in occluded space

# %%
movetwo_data = pd.read_csv('2022-02-18-17-31-32 2022-02-21 22_19_37-gps_data_lab2.csv')

# %%
e3=movetwo_data['.utm_easting']
n3=movetwo_data['.utm_northing']
a3=movetwo_data['.altitude']

# %%
plt.plot(e3,n3,'go')
plt.show

plt.title('Position Coordinates')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
plt.grid()

# %%
#altitude plot with its mean line
plt.plot(a3,'r.')
plt.show
plt.title('Altitude Plot')
plt.xlabel('Time in seconds')
plt.ylabel('Altitude in meters')
plt.show
plt.hlines(movetwo_data['.altitude'].mean(), xmin=0 , xmax=140)
plt.grid()

# %%
#SDE=movetwo_data['.utm_easting'].std()
#SDN=movetwo_data['.utm_northing'].std()
SDA=movetwo_data['.altitude'].std()

# %%
SDA
# Out:
# 0.10257080486245479

# %%
e31 = np.array(e3)
n31 = np.array(n3)
a31 = np.array(a3)

# %%
#I am going to divide the square looking path to four lines and analyze for each sides for better understanding and visualization.

# %%
#first side
e311 = e31[0:20]
n311 = n31[0:20]
a311 = a31[0:20]
plt.plot(e311,n311,'o')


plt.title('Position Coordinates of first side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')



x = np.array(e311)
y = np.array(n311)
m, b = np.polyfit(e311,n311, 1)
plt.plot(x, m*e311 + b)
plt.grid()

# %%
new_y1 = m*e311 + b

# %%
new_y1.size
# Out:
# 20

# %%
np.array(n311).size
# Out:
# 20

# %%
#calculation of mean square error
np.array(new_y1)
MS=np.square(np.array(new_y1)-np.array(n311))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/20
print(MSE)
# Out:
# 0.012079938681173252

# %%
#second side
e312 = e31[21:58]
n312 = n31[21:58]
a312 = a31[21:58]
plt.plot(e312,n312,'go')
plt.show



plt.title('Position Coordinates of second side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
x = np.array(e312)
y = np.array(n312)
m, b = np.polyfit(e312,n312, 1)
plt.plot(x, m*e312 + b)
plt.grid()

# %%
new_y4 = m*e312 + b

# %%
new_y4.size
# Out:
# 37

# %%
np.array(n312).size
# Out:
# 37

# %%
#mean square error
np.array(new_y4)
MS=np.square(np.array(new_y4)-np.array(n312))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/37
print(MSE)
# Out:
# 1.9802618450766978

# %%
#third side
e313 = e31[59:94]
n313 = n31[59:94]
a313 = a31[59:94]
plt.plot(e313,n313,'go')
plt.show



plt.title('Position Coordinates of third side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
x = np.array(e313)
y = np.array(n313)
m, b = np.polyfit(e313,n313, 1)
plt.plot(x, m*e313 + b)
plt.grid()

# %%
new_y4 = m*e313 + b

# %%
new_y4.size
# Out:
# 35

# %%
np.array(n313).size
# Out:
# 35

# %%
#mean square error
np.array(new_y4)
MS=np.square(np.array(new_y4)-np.array(n313))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/35
print(MSE)
# Out:
# 0.008045813065482696

# %%
#fourth side

# %%
e314 = e31[94:141]
n314 = n31[94:141]
a314 = a31[94:141]
plt.plot(e314,n314,'go')
plt.show



plt.title('Position Coordinates of fourth side')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
x = np.array(e314)
y = np.array(n314)
m, b = np.polyfit(e314,n314, 1)
plt.plot(x, m*e314 + b)
plt.grid()

# %%
new_y4 = m*e314 + b

# %%
new_y4.size
# Out:
# 47

# %%
np.array(n314).size
# Out:
# 47

# %%
#mean square error
np.array(new_y4)
MS=np.square(np.array(new_y4)-np.array(n314))
sum = 0
for i in MS:
    sum=sum+i
MSE=sum/47
print(MSE)
# Out:
# 0.8861922971220054

# %%
#Analysis of stationary data in an occluded space.

# %%
stattwo_data = pd.read_csv('2022-02-18-18-20-44 2022-02-21 22_19_07-gps_data_lab2.csv')

# %%
e4=stattwo_data['.utm_easting']
n4=stattwo_data['.utm_northing']
a4=stattwo_data['.altitude']

# %%
plt.plot(e4,n4,'.')
plt.show

plt.title('Position Coordinates')
plt.xlabel('UTM Easting in metres')
plt.ylabel('UTM Northing in metres')
plt.grid()

# %%
#plot of altitude with its mean line

# %%
plt.plot(a4,'r.')
plt.show
plt.title('Altitude Plot')
plt.xlabel('Time in seconds')
plt.ylabel('Altitude in meters')
plt.show
plt.hlines(stattwo_data['.altitude'].mean(), xmin=0 , xmax=641)
plt.grid()

# %%
SDE=stattwo_data['.utm_easting'].std()
SDN=stattwo_data['.utm_northing'].std()
SDA=stattwo_data['.altitude'].std()

# %%
SDE #standard deviation of utm easting
# Out:
# 0.09800500577610387

# %%
SDA #standard deviation of altitude
# Out:
# 0.9878523088434642

# %%
SDN #standard deviation of utm northing
# Out:
# 0.38581442693642787
